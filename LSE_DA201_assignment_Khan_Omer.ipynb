# %% [markdown]
# ### LSE Data Analytics Online Career Accelerator
#
# # Course 2: Data Analytics using Python

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 1

# %% [markdown]
# ### Insert proof of your GitHub repository. This can be a link or screenshot showing your repo.

# %% [markdown]
# # My GitHub repository.
# # https://github.com/mojoom/LSE_DA_NHS_Assignment

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 2

# %% [markdown]
# ### Prepare your workstation

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Optional - Ignore warnings.
import warnings
warnings.filterwarnings('ignore')

# %%
# Import and sense-check the actual_duration.csv data set as ad.
ad = pd.read_csv('actual_duration.csv')

# View the DataFrame.
#check number of rows and columns
print(ad.shape)

#check column names
print(ad.columns)

#check data type
ad.dtypes
# Out:
# (137793, 8)
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
#check right data type for actual_duration.csv
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# Determine whether there are missing values.
ad.isna().sum().sum()
# Out:
# 0

# %%
# Determine the metadata of the data set.
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Determine the descriptive statistics of the data set.
stats_ad = ad.describe(include='all')
print (stats_ad)
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# count                 137793                    137793
# unique                   106                       106
# top                      26A                 E38000239
# freq                    1484                      1484
# mean                     NaN                       NaN
# std                      NaN                       NaN
# min                      NaN                       NaN
# 25%                      NaN                       NaN
# 50%                      NaN                       NaN
# 75%                      NaN                       NaN
# max                      NaN                       NaN
#
#                     sub_icb_location_name icb_ons_code region_ons_code  \
# count                              137793       137793          137793
# unique                                106           42               7
# top     NHS Norfolk and Waveney ICB - 26A    E54000057       E40000010
# ...

# %%
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Import and sense-check the appointments_regional.csv data set as ar.
ar = pd.read_csv('appointments_regional.csv')

# View the DataFrame.
#check number of rows and columns
print(ar.shape)

#check column names
print(ar.columns)

#check data type
ar.dtypes
# Out:
# (596821, 7)
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
#check right data type for appointments_regional.csv
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Determine whether there are missing values.
ar.isna().sum().sum()
# Out:
# 0

# %%
# Determine the metadata of the data set.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Determine the descriptive statistics of the data set.
stats_ar = ar.describe(include='all')
print (stats_ar)
# Out:
#        icb_ons_code appointment_month appointment_status  \
# count        596821            596821             596821
# unique           42                30                  3
# top       E54000057           2020-03           Attended
# freq          54527             21350             232137
# mean            NaN               NaN                NaN
# std             NaN               NaN                NaN
# min             NaN               NaN                NaN
# 25%             NaN               NaN                NaN
# 50%             NaN               NaN                NaN
# 75%             NaN               NaN                NaN
# max             NaN               NaN                NaN
#
#                     hcp_type appointment_mode  \
# count                 596821           596821
# unique                     3                5
# top     Other Practice staff     Face-to-Face
# freq                  241557           180410
# ...

# %%
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Import and sense-check the national_categories.xlsx data set as nc.
nc = pd.read_excel('national_categories.xlsx')

# View the DataFrame.
#check number of rows and columns
print(nc.shape)

#check column names
print(nc.columns)

#check data type
nc.dtypes
# Out:
# (817394, 8)
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
#check right data type for national_categories.xlsx
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Determine whether there are missing values.
nc.isnull().sum().sum()
# Out:
# 0

# %%
# Determine the metadata of the data set.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine the descriptive statistics of the data set.
stats_nc = nc.describe(include='all')
print (stats_nc)
# Out:
#            appointment_date icb_ons_code              sub_icb_location_name  \
# count                817394       817394                             817394
# unique                  334           42                                106
# top     2022-06-28 00:00:00    E54000057  NHS North West London ICB - W2U3Z
# freq                   3536        59180                              13007
# first   2021-08-01 00:00:00          NaN                                NaN
# last    2022-06-30 00:00:00          NaN                                NaN
# mean                    NaN          NaN                                NaN
# std                     NaN          NaN                                NaN
# min                     NaN          NaN                                NaN
# 25%                     NaN          NaN                                NaN
# 50%                     NaN          NaN                                NaN
# ...

# %%
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %% [markdown]
# ### Explore the data set

# %% [markdown]
# **Question 1:** How many locations are there in the data set?

# %%
# Determine the number of locations.
loc_nc = nc.sub_icb_location_name.value_counts()

#print locations in descending order
print(loc_nc)

# count total number of unique locations
count_loc= len(loc_nc)

#print results
print("Count of locations:", count_loc)
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
#                                                ...
# NHS North East and North Cumbria ICB - 00N      4210
# NHS Lancashire and South Cumbria ICB - 02G      4169
# NHS Cheshire and Merseyside ICB - 01V           3496
# NHS Cheshire and Merseyside ICB - 01T           3242
# NHS Greater Manchester ICB - 00V                2170
# Name: sub_icb_location_name, Length: 106, dtype: int64
# Count of locations: 106

# %% [markdown]
# **Question 2:** What are the five locations with the highest number of records?

# %%
# Determine the top five locations based on record count.
loc_nc.head()
# Out:
# NHS North West London ICB - W2U3Z              13007
# NHS Kent and Medway ICB - 91Q                  12637
# NHS Devon ICB - 15N                            12526
# NHS Hampshire and Isle Of Wight ICB - D9Y0V    12171
# NHS North East London ICB - A3A8R              11837
# Name: sub_icb_location_name, dtype: int64

# %% [markdown]
# **Question 3:** How many service settings, context types, national categories, and appointment statuses are there?

# %%
# Determine the number of service settings.
service_set_nc = nc.service_setting.value_counts()
#print service settings
print(service_set_nc)

#count total number of service settings
count_ser_set = nc.service_setting.unique().size
#print results
print("Service settings: "+ str(count_ser_set))
# Out:
# General Practice             359274
# Primary Care Network         183790
# Other                        138789
# Extended Access Provision    108122
# Unmapped                      27419
# Name: service_setting, dtype: int64
# Service settings: 5

# %%
# Determine the number of context types.
context_type = nc.context_type.value_counts()
# print outcome
print(context_type)
# count total number of different context types
count_cont = nc.context_type.unique().size
#print outcome
print("Context types: "+ str(count_cont))
# Out:
# Care Related Encounter    700481
# Inconsistent Mapping       89494
# Unmapped                   27419
# Name: context_type, dtype: int64
# Context types: 3

# %%
# Determine the number of national categories.
nat_cat_nc = nc.national_category.value_counts()
# print outcome
print(nat_cat_nc)

#count different national categories
count_nat_cat = nc.national_category.unique().size
#print outcome
print("national categories: "+ str(count_nat_cat))
# Out:
# Inconsistent Mapping                                                   89494
# General Consultation Routine                                           89329
# General Consultation Acute                                             84874
# Planned Clinics                                                        76429
# Clinical Triage                                                        74539
# Planned Clinical Procedure                                             59631
# Structured Medication Review                                           44467
# Service provided by organisation external to the practice              43095
# Home Visit                                                             41850
# Unplanned Clinical Activity                                            40415
# Patient contact during Care Home Round                                 28795
# Unmapped                                                               27419
# ...

# %%
# Determine the number of appointment status.
app_stat_ar = ar.appointment_status.value_counts()
#print outcome
print(app_stat_ar)
# count types of appointment status
count_app = ar.appointment_status.unique().size
#print outcome
print("Appointment statuses: "+ str(count_app))
# Out:
# Attended    232137
# Unknown     201324
# DNA         163360
# Name: appointment_status, dtype: int64
# Appointment statuses: 3

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 3

# %% [markdown]
# ### Continue to explore the data and search for answers to more specific questions posed by the NHS.

# %% [markdown]
# **Question 1:** Between what dates were appointments scheduled?

# %%
# View the first five rows of appointment_date for the ad DataFrame to determine the date format.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# ...

# %%
# View the first five rows of appointment_date for the nc DataFrame to determine the date format.
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# ...

# %%
# Change the date format of ad['appointment_date'].
from datetime import date
ad['appointment_date'] = pd.to_datetime(ad["appointment_date"])
# View the DateFrame.
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0       2021-12-01           31-60 Minutes                    364
# 1       2021-12-01           21-30 Minutes                    619
# ...

# %%
# Change the date format of ar['appointment_month'].
ar['appointment_month'] = pd.to_datetime(ar["appointment_month"])

# View the DateFrame.
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
# Determine the minimum and maximum dates in the ad DataFrame.
min_ad_date = ad['appointment_date'].min()
max_ad_date = ad['appointment_date'].max()

print("Min date:", min_ad_date)
print("Max date:", max_ad_date)
# Out:
# Min date: 2021-12-01 00:00:00
# Max date: 2022-06-30 00:00:00

# %%
# Determine the minimum and maximum dates in the nc DataFrame.
# Use appropriate docstrings.
min_nc_date = nc['appointment_date'].min()
max_nc_date = nc['appointment_date'].max()

print("Min date:", min_nc_date)
print("Max date:", max_nc_date)
# Out:
# Min date: 2021-08-01 00:00:00
# Max date: 2022-06-30 00:00:00

# %% [markdown]
# **Question 2:** Which service setting was the most popular for NHS North West London from 1 January to 1 June 2022?

# %%
# create subset by date range 
nc_date = nc[(nc['appointment_date'] > '2022-1-1') & (nc['appointment_date'] <= '2022-6-1')]
#subset by date range and NHS North West london
nc_loc = nc_date.loc[(nc["sub_icb_location_name"]=="NHS North West London ICB - W2U3Z")]

#check data
nc_loc.head()
# Out:
#        appointment_date icb_ons_code              sub_icb_location_name  \
# 800304       2022-01-02    E54000027  NHS North West London ICB - W2U3Z
# 800305       2022-01-02    E54000027  NHS North West London ICB - W2U3Z
# 800306       2022-01-02    E54000027  NHS North West London ICB - W2U3Z
# 800307       2022-01-02    E54000027  NHS North West London ICB - W2U3Z
# 800308       2022-01-02    E54000027  NHS North West London ICB - W2U3Z
#
#              service_setting            context_type     national_category  \
# 800304              Unmapped                Unmapped              Unmapped
# 800305  Primary Care Network  Care Related Encounter       Planned Clinics
# 800306  Primary Care Network  Care Related Encounter       Clinical Triage
# 800307      General Practice    Inconsistent Mapping  Inconsistent Mapping
# 800308      General Practice  Care Related Encounter               Walk-in
#
#         count_of_appointments appointment_month
# ...

# %%
# total count of appointments per setting type
nc_date_loc_count = nc_loc.loc[:,['sub_icb_location_name','service_setting','count_of_appointments']].groupby(['sub_icb_location_name','service_setting']).sum()
#view outcome
nc_date_loc_count
# Out:
#                                                              count_of_appointments
# sub_icb_location_name             service_setting
# NHS North West London ICB - W2U3Z Extended Access Provision                  98087
#                                   General Practice                         4804011
#                                   Other                                     152896
#                                   Primary Care Network                      109792
#                                   Unmapped                                  390610

# %% [markdown]
# **Question 3:** Which month had the highest number of appointments?

# %%
# Number of appointments per month
total_app_m = nc.groupby(pd.Grouper(key='appointment_date', axis=0, freq='M')).sum()
#sort descending
total_app_m.sort_values(by='count_of_appointments', ascending=False)
# Out:
#                   count_of_appointments
# appointment_date
# 2021-11-30                     30405070
# 2021-10-31                     30303834
# 2022-03-31                     29595038
# 2021-09-30                     28522501
# 2022-05-31                     27495508
# 2022-06-30                     25828078
# 2022-01-31                     25635474
# 2022-02-28                     25355260
# 2021-12-31                     25140776
# 2022-04-30                     23913060
# 2021-08-31                     23852171

# %% [markdown]
# **Question 4:** What was the total number of records per month?

# %%
# Total number of records per month.
#answered above

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 4

# %% [markdown]
# ### Create visualisations and identify possible monthly and seasonal trends in the data.

# %%
# Import the necessary libraries.
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# %% [markdown]
# ### Objective 1
# Create three visualisations indicating the number of appointments per month for service settings, context types, and national categories.

# %%
# Change the data type of the appointment month to string to allow for easier plotting.
nc['appointment_month']=pd.Series(nc['appointment_month'], dtype="string")
#check change
nc['appointment_month'].dtypes
# Out:
# string[python]

# %%
# Aggregate on monthly level and determine the sum of records per month.
nc_ss = nc.groupby(['appointment_month', 'service_setting'])\
[['count_of_appointments']].sum()

# View output.
nc_ss.head()
# Out:
#                                              count_of_appointments
# appointment_month service_setting
# 2021-08           Extended Access Provision                 160927
#                   General Practice                        21575852
#                   Other                                     449101
#                   Primary Care Network                      432448
#                   Unmapped                                 1233843

# %% [markdown]
# **Service settings:**

# %%
# Plot the appointments over the available date range, and review the service settings for months.
# Create a lineplot.
sns.lineplot(x="appointment_month", y="count_of_appointments",hue="service_setting",\
             style="service_setting",ci=None, data=nc_ss).set(title='Service Setting Monthly Count')
# Out:
# [Text(0.5, 1.0, 'Service Setting Monthly Count')]

# %% [markdown]
# **Context types:**

# %%
# Create a separate data set that can be used in future weeks. 
nc_ct = nc.groupby(['appointment_month', 'context_type'])[['count_of_appointments']].sum()
# View output.
nc_ct.head()
# Out:
#                                           count_of_appointments
# appointment_month context_type
# 2021-08           Care Related Encounter               20255235
#                   Inconsistent Mapping                  2363093
#                   Unmapped                              1233843
# 2021-09           Care Related Encounter               24404251
#                   Inconsistent Mapping                  2782135

# %%
# Plot the appointments over the available date range, and review the context types for months.
# Create a lineplot.
sns.lineplot(x="appointment_month", y="count_of_appointments",hue="context_type",\
style="context_type",ci=None, data=nc_ct).set(title='Context Type Monthly Count')
# Out:
# [Text(0.5, 1.0, 'Context Type Monthly Count')]

# %% [markdown]
# **National categories:**

# %%
# Create a separate data set that can be used in future weeks. 

nc_nc = nc.groupby(['appointment_month', 'national_category'])\
[['count_of_appointments']].sum()
# View output.
nc_nc.head()
# Out:
#                                                                       count_of_appointments
# appointment_month national_category
# 2021-08           Care Home Needs Assessment & Personalised Care ...                  29676
#                   Care Home Visit                                                     47583
#                   Clinical Triage                                                   3704207
#                   General Consultation Acute                                        4280920
#                   General Consultation Routine                                      7756045

# %%
# Plot the appointments over the available date range, and review the national categories for months.
# Create a lineplot.
sns.lineplot(x="appointment_month", y="count_of_appointments",hue="national_category",\
style="national_category",ci=None, data=nc_nc).set(title='National Categories Monthly Count')
# Out:
# [Text(0.5, 1.0, 'National Categories Monthly Count')]

# %% [markdown]
# ### Objective 2
# Create four visualisations indicating the number of appointments for service setting per season. The seasons are summer (August 2021), autumn (October 2021), winter (January 2022), and spring (April 2022).

# %% [markdown]
# **Summer (August 2021):**

# %%
# Create a separate data set that can be used in future weeks. 

nc_aug = nc[(nc['appointment_month'] =='2021-08')]
nc_ss_aug = nc_aug.groupby(['appointment_date','appointment_month',\
                            'service_setting'])[['count_of_appointments']].sum()

# View output.
nc_ss_aug.head()
# Out:
#                                                               count_of_appointments
# appointment_date appointment_month service_setting
# 2021-08-01       2021-08           Extended Access Provision                    438
#                                    General Practice                            3411
#                                    Other                                        401
#                                    Primary Care Network                         323
#                                    Unmapped                                    1054

# %%
# Look at August 2021 in more detail to allow a closer look.
# Create a lineplot.
sns.lineplot(x="appointment_date", y="count_of_appointments",hue="service_setting",\
             style="service_setting",ci=None, data=nc_ss_aug).set\
(title='Summer Service Setting Appointments')
# Out:
# [Text(0.5, 1.0, 'Summer Service Setting Appointments')]

# %% [markdown]
# **Autumn (October 2021):**

# %%
# Look at October 2021 in more detail to allow a closer look.
# Create a lineplot.
nc_oct = nc[(nc['appointment_month'] =='2021-10')]

nc_ss_oct = nc_oct.groupby(['appointment_date','appointment_month',\
                            'service_setting'])[['count_of_appointments']].sum()

sns.lineplot(x="appointment_date", y="count_of_appointments",hue="service_setting",\
             style="service_setting",ci=None, data=nc_ss_oct).set\
(title='Autumn Service Setting Appointments')
# Out:
# [Text(0.5, 1.0, 'Autumn Service Setting Appointments')]

# %% [markdown]
# **Winter (January 2022):**

# %%
# Look at January 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_jan = nc[(nc['appointment_month'] =='2022-01')]

nc_ss_jan = nc_jan.groupby(['appointment_date','appointment_month',\
                            'service_setting'])[['count_of_appointments']].sum()

sns.lineplot(x="appointment_date", y="count_of_appointments",hue="service_setting",\
             style="service_setting",ci=None, data=nc_ss_jan).set\
(title='Winter Service Setting Appointments')
# Out:
# [Text(0.5, 1.0, 'Winter Service Setting Appointments')]

# %% [markdown]
# **Spring (April 2022):**

# %%
# Look at April 2022 in more detail to allow a closer look.
# Create a lineplot.
nc_apr = nc[(nc['appointment_month'] =='2022-04')]

nc_ss_apr = nc_apr.groupby(['appointment_date','appointment_month',\
                            'service_setting'])[['count_of_appointments']].sum()

sns.lineplot(x="appointment_date", y="count_of_appointments",hue="service_setting",\
             style="service_setting",ci=None, data=nc_ss_apr).set\
(title='Spring Service Setting Appointments')
# Out:
# [Text(0.5, 1.0, 'Spring Service Setting Appointments')]

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 5

# %% [markdown]
# ### Analyse tweets from Twitter with hashtags related to healthcare in the UK.

# %%
# Libraries and settings needed for analysis
import pandas as pd
import seaborn as sns

# Set figure size.
sns.set(rc={'figure.figsize':(15, 12)})

# Set the plot style as white.
sns.set_style('white')

# Maximum column width to display
pd.options.display.max_colwidth = 200

# %%
# Load the data set.
tweets = pd.read_csv('tweets.csv')

# View the DataFrame.
tweets.head()
# Out:
#               tweet_id                                    tweet_full_text  \
# 0  1567629223795527681  As Arkansas’ first Comprehensive Stroke Certif...
# 1  1567582846612553728  RT @AndreaGrammer: Work-life balance is at the...
# 2  1567582787070304256  RT @OntarioGreens: $10 billion can go a long w...
# 3  1567582767625428992  RT @modrnhealthcr: 🚨#NEW:🚨 Insurance companies...
# 4  1567582720460570625  ICYMI: Our recent blogs on Cybersecurity in Ac...
#
#                                       tweet_entities  \
# 0  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 1  {'hashtags': [{'text': 'PremiseHealth', 'indic...
# 2  {'hashtags': [{'text': 'Healthcare', 'indices'...
# 3  {'hashtags': [{'text': 'NEW', 'indices': [20, ...
# 4  {'hashtags': [{'text': 'blogs', 'indices': [18...
#
#                              tweet_entities_hashtags  \
# 0                                        #Healthcare
# 1                            #PremiseHealth, #hiring
# ...

# %%
# Explore the metadata.
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tweet_id                 1174 non-null   int64
#  1   tweet_full_text          1174 non-null   object
#  2   tweet_entities           1174 non-null   object
#  3   tweet_entities_hashtags  1007 non-null   object
#  4   tweet_metadata           1174 non-null   object
#  5   tweet_retweet_count      1174 non-null   int64
#  6   tweet_favorite_count     1174 non-null   int64
#  7   tweet_favorited          1174 non-null   bool
#  8   tweet_retweeted          1174 non-null   bool
#  9   tweet_lang               1174 non-null   object
# dtypes: bool(2), int64(3), object(5)
# memory usage: 75.8+ KB

# %%
# Explore the data set.
tweets.describe()
# Out:
#            tweet_id  tweet_retweet_count  tweet_favorite_count
# count  1.174000e+03          1174.000000            1174.00000
# mean   1.567612e+18             8.629472               0.37138
# std    2.427553e+13            29.784675               2.04470
# min    1.567574e+18             0.000000               0.00000
# 25%    1.567590e+18             0.000000               0.00000
# 50%    1.567611e+18             1.000000               0.00000
# 75%    1.567633e+18             3.000000               0.00000
# max    1.567655e+18           303.000000              42.00000

# %%
# Would it be useful to only look at retweeted and favourite tweet messages?
# Explain your answer.
rt = tweets.tweet_retweet_count.value_counts()
fv = tweets.tweet_favorite_count.value_counts()
print (rt, fv)
# Out:
# 0      526
# 1      215
# 2      114
# 3       70
# 5       35
# 4       27
# 7       18
# 12      16
# 8       15
# 73      14
# 9       13
# 6       12
# 208     12
# 35      10
# 37       6
# 11       6
# 10       5
# 53       5
# 44       4
# 150      4
# 63       4
# 76       3
# 85       3
# 41       3
# 62       3
# 207      3
# 68       3
# 78       2
# 23       2
# 24       2
# 72       2
# 16       2
# 13       1
# 49       1
# 48       1
# 15       1
# 107      1
# 14       1
# 79       1
# 20       1
# 39       1
# 19       1
# 303      1
# 57       1
# 40       1
# 54       1
# 169      1
# Name: tweet_retweet_count, dtype: int64 0     1027
# 1       91
# 2       16
# 3       13
# 4        7
# 5        5
# 6        2
# 17       1
# 12       1
# 10       1
# 8        1
# 13       1
# 11       1
# 7        1
# 20       1
# 28       1
# 14       1
# 18       1
# 9        1
# 42       1
# Name: tweet_favorite_count, dtype: int64

# %%
# Create subset dataframe of the text column
tweet_texts = tweets[['tweet_full_text']]

#Create a new column that captures the specific hashtags
tweet_texts['tags'] = tweet_texts.tweet_full_text.apply(lambda x: ([x for x in x.split(" ") if x.startswith("#")]))

# Seperate the hashtags in the same tweet and store it in a new df
tags = tweet_texts.explode('tags')

#Drop the text column so you have a pandas series with just the hashtags
tags.drop('tweet_full_text', axis=1, inplace=True)

# Clean the key words
tags['tags'] = tags['tags'].replace({'#':''}, regex=True)
tags = tags.dropna()
tags = tags["tags"].str.lower() 
# View the DataFrame showing top 30 records
tags.head(30)
# Out:
# 0                        healthcare
# 1                     premisehealth
# 1                            hiring
# 2                        healthcare
# 4             digitaltransformation
# 4                     cybersecurity
# 4                        accounting
# 4                           finance
# 4                        healthcare
# 5                           cnaexam
# 5                cnaexampreparation
# 5                      jacksonville
# 5                       cnatraining
# 5                             nurse
# 5                           nursing
# 5                         nurselife
# 5                 nursepractitioner
# 5                     nurseproblems
# 5                     nursingschool
# 5                        healthcare
# 6                      disparities.
# 6                             alert
# 6                         insurance
# 6     data\nhttps://t.co/h9hlamr7p9
# 7                        healthcare
# 8                        healthcare
# ...

# %%
# convert series to Dataframe
tags.value_counts()
# Out:
# healthcare                            716
# health                                 80
# medicine                               41
# ai                                     40
# job                                    38
#                                      ...
# safesex                                 1
# reproductivehealth                      1
# clincalresearch                         1
# southernclinicalresearchassociates      1
# physiotherapy                           1
# Name: tags, Length: 1462, dtype: int64

# %%
#value.counts() for tags
tag_data = tags_df.value_counts().reset_index()

#change columns to 'word' and 'count'
tag_data.columns = ['word', 'count']

# check count is integer
print (tag_data.dtypes)

#check data
tag_data.head()
# Out:
# word     object
# count     int64
# dtype: object
#          word  count
# 0  healthcare    716
# 1      health     80
# 2    medicine     41
# 3          ai     40
# 4         job     38

# %%
# Display records where the count is larger than 10
# check tail has more than 10 counts

tag_10 = tag_data.loc[tag_data['count'] > 10]
print (tag_10.tail())

# Create a Seaborn barplot indicating records with a count >10 records.
tweet_plot = sns.barplot(x="word", y='count', estimator=sum, data=tag_10).set\
(title='>10 Hashtags')
plt.xticks(rotation=90)
plt.xlabel("Hashtags", fontsize= 12)
plt.ylabel("Count", fontsize= 12)
# Out:
#                      word  count
# 41  digitaltransformation     11
# 42           healthcareit     11
# 43                 nurses     11
# 44             innovation     11
# 45             telehealth     11
# Text(0, 0.5, 'Count')

# %%
# check for outliers
sns.boxplot(y='count', data=tag_10)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
#remove outliers
tag_out = tag_10[(tag_10['count'] > 10) & (tag_10['count'] < 41 )]

#improved bar graph
tweet_plot = sns.barplot(x="word", y='count', estimator=sum, data=tag_out).set\
(title= 'Hashtags wihtout outliers')
plt.xticks(rotation=90)
plt.xlabel("Hashtags", fontsize= 12)
plt.ylabel("Count", fontsize= 12)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #

# %% [markdown]
# # Assignment activity 6

# %% [markdown]
# ### Investigate the main concerns posed by the NHS.

# %%
# Prepare your workstation.
# View the DataFrame.

print(ar.shape)
print(ar.dtypes)
ar.head()
# Out:
# (596821, 7)
# icb_ons_code                                 object
# appointment_month                    datetime64[ns]
# appointment_status                           object
# hcp_type                                     object
# appointment_mode                             object
# time_between_book_and_appointment            object
# count_of_appointments                         int64
# dtype: object
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 1    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 2    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 3    E54000034        2020-01-01           Attended       GP     Face-to-Face
# 4    E54000034        2020-01-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# ...

# %%
# Print the min and max dates.
print(ar['appointment_month'].max())
print(ar['appointment_month'].min())
# Out:
# 2022-06-01 00:00:00
# 2020-01-01 00:00:00

# %%
# Filter the data set to only look at data from 2021-08 onwards.
ar_aug = ar[ar['appointment_month'] >='2021-08']
#view data 
ar_aug.head()
# Out:
#      icb_ons_code appointment_month appointment_status hcp_type  \
# 3652    E54000034        2021-08-01           Attended       GP
# 3653    E54000034        2021-08-01           Attended       GP
# 3654    E54000034        2021-08-01           Attended       GP
# 3655    E54000034        2021-08-01           Attended       GP
# 3656    E54000034        2021-08-01           Attended       GP
#
#      appointment_mode time_between_book_and_appointment  count_of_appointments
# 3652     Face-to-Face                             1 Day                   6553
# 3653     Face-to-Face                    15  to 21 Days                   2390
# 3654     Face-to-Face                       2 to 7 Days                  10547
# 3655     Face-to-Face                    22  to 28 Days                    937
# 3656     Face-to-Face                     8  to 14 Days                   4961

# %% [markdown]
# **Question 1:** Should the NHS start looking at increasing staff levels?

# %%
# Create an aggregated data set to review the different features.

ar_agg = ar_aug.groupby(['appointment_month', 'hcp_type', 'appointment_status',\
'appointment_mode','time_between_book_and_appointment'])[['count_of_appointments']]\
.sum().reset_index().copy()

# View the DataFrame.
ar_agg.head()
# Out:
#   appointment_month hcp_type appointment_status appointment_mode  \
# 0        2021-08-01       GP           Attended     Face-to-Face
# 1        2021-08-01       GP           Attended     Face-to-Face
# 2        2021-08-01       GP           Attended     Face-to-Face
# 3        2021-08-01       GP           Attended     Face-to-Face
# 4        2021-08-01       GP           Attended     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                 507835
# 1                    15  to 21 Days                 194726
# 2                       2 to 7 Days                 959486
# 3                    22  to 28 Days                 102111
# 4                     8  to 14 Days                 398772

# %%
# Determine the total number of appointments per month.

ar_df = ar_agg.groupby(['appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

print (ar_df)
# Add a new column to indicate the average utilisation of services.
# Monthly aggregate / 30 to get to a daily value.

ar_df['utilisation'] = ar_df['count_of_appointments'] / 30

#round to 1 decimal
ar_df['utilisation'] = ar_df['utilisation'].round(decimals = 0)

# View the DataFrame.
print (ar_df)
# Out:
#    appointment_month  count_of_appointments
# 0         2021-08-01               23852171
# 1         2021-09-01               28522501
# 2         2021-10-01               30303834
# 3         2021-11-01               30405070
# 4         2021-12-01               25140776
# 5         2022-01-01               25635474
# 6         2022-02-01               25355260
# 7         2022-03-01               29595038
# 8         2022-04-01               23913060
# 9         2022-05-01               27495508
# 10        2022-06-01               25828078
#    appointment_month  count_of_appointments  utilisation
# 0         2021-08-01               23852171     795072.0
# 1         2021-09-01               28522501     950750.0
# 2         2021-10-01               30303834    1010128.0
# 3         2021-11-01               30405070    1013502.0
# 4         2021-12-01               25140776     838026.0
# 5         2022-01-01               25635474     854516.0
# ...

# %%
# Plot sum of count of monthly visits.
# Convert the appointment_month to string data type for ease of visualisation.

ar_df['appointment_month']=pd.Series(ar_df['appointment_month'], dtype="string")
# Create a lineplot with Seaborn.
sns.lineplot(x='appointment_month', y='count_of_appointments', data=ar_df, ci=None,).set(title='Monthly Appointments')
# Out:
# [Text(0.5, 1.0, 'Monthly Appointments')]

# %%
# Plot monthly capacity utilisation.
sns.lineplot(x='appointment_month', y='utilisation', data=ar_df, ci=None).set(title='monthly capacity utilisation')
plt.axhline(y=1200000, xmin=0, xmax=1, c= 'red')
# Create a lineplot.

# %% [markdown]
# **Question 2:** How do the healthcare professional types differ over time?

# %%
# Create a line plot to answer the question.
hcp_type = ar_aug.groupby(['hcp_type', 'appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

sns.lineplot(x='appointment_month', y='count_of_appointments', hue='hcp_type',\
data=hcp_type[hcp_type['hcp_type'] != 'Unknown'],\
ci=None).set(title= 'Healthcare Professional types over time')
# Out:
# [Text(0.5, 1.0, 'Healthcare Professional types over time')]

# %% [markdown]
# **Question 3:** Are there significant changes in whether or not visits are attended?

# %%
# Create a line plot to answer the question.
na = ar_aug[(ar_aug['appointment_status'] == 'DNA')]
            

sns.lineplot(x="appointment_month", y="count_of_appointments",hue="hcp_type",\
             style="hcp_type",ci=None, data=na).set(title= 'Missed appointments by HCP Type')
# Out:
# [Text(0.5, 1.0, 'Missed appointments by HCP Type')]

# %% [markdown]
# **Question 4:** Are there changes in terms of appointment type and the busiest months?

# %%
# Create a line plot to answer the question.
sns.lineplot(x="appointment_month", y="count_of_appointments",hue="appointment_mode",\
             ci=None, data=na).set(title= 'Types of appointment missed by month')
# Out:
# [Text(0.5, 1.0, 'Types of appointment missed by month')]

# %% [markdown]
# **Question 5:** Are there any trends in time between booking an appointment?

# %%
# Create a line plot to answer the question.
sns.lineplot(x="time_between_book_and_appointment", y="count_of_appointments",hue="appointment_status",\
             ci=None, data=ar_aug).set(title= 'Time between booking and appointment status')
# Out:
# [Text(0.5, 1.0, 'Time between booking and appointment status')]

# %% [markdown]
# **Question 6:** How do the spread of service settings compare?

# %%
# Let's go back to the national category DataFrame you created in an earlier assignment activity.

# %%
# Create a new DataFrame consisting of the month of appointment and the number of appointments.
nc_month = nc.groupby(['appointment_month'])[['count_of_appointments']]\
.sum().reset_index().copy()

nc_month.head()
# View the DataFrame.
# Out:
#   appointment_month  count_of_appointments
# 0           2021-08               23852171
# 1           2021-09               28522501
# 2           2021-10               30303834
# 3           2021-11               30405070
# 4           2021-12               25140776

# %%
# Create a boxplot to investigate spread of service settings.
sns.boxplot(x='service_setting', y='count_of_appointments', data=nc)
plt.title("Service Setting Spread")
# Out:
# Text(0.5, 1.0, 'Service Setting Spread')

# %%
# Create a boxplot to investigate the service settings without GP.
nc_sansgp = nc.loc[nc["service_setting"] != 'General Practice']


sns.boxplot(x='service_setting', y='count_of_appointments', data=nc_sansgp)
plt.title("Monthly Appointment Count")
# Out:
# Text(0.5, 1.0, 'Monthly Appointment Count')

# %% [markdown]
# #

# %% [markdown]
# ### Provide a summary of your findings and recommendations based on the analysis.

# %% [markdown]
# > It can be observed that the resources were not used at capacity. At all times appointments made were well below capacity of 1,200,000 suggesting that there is in fact adequate staffing and resourcing which can be better used. It is also seen that hte peak missed appointments occured around October 2021 in Other settings, likely due to the limiting of services due to Covid-19. The analysis also suggests that patients are most punctual in attending when appointments are booked on the same day - this should be further explored to optimise patient attendance when appointments have been booked in advance.
